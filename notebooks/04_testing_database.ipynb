# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('..'))

from calls import database_config
import pandas as pd

# example of inserting a document! now it appears in the actual database!
doc = {"name": "Alic", "age": 21, "role": "tester"}
database_config.insert_one(database_config.users_collection, doc)
# Out:
# InsertOneResult(ObjectId('690dca3906fbcc4ce0f58339'), acknowledged=True)

# %%
database_config.delete_many(database_config.users_collection, {"name": "Alic"})
database_config.delete_one(database_config.users_collection, {"name": "Alice"})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000038'), 'opTime': {'ts': Timestamp(1762511443, 3), 't': 56}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1762511443, 3), 'signature': {'hash': b'\x13\xec\x0702\xee\x98#O\xc7\xbdq\xd7\xb6\xe9\xf0\xaf`\xd3!', 'keyId': 7517677490949586946}}, 'operationTime': Timestamp(1762511443, 3)}, acknowledged=True)
